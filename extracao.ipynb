# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl 
import matplotlib.dates as mdates
import seaborn as sns 
import os
import calendar
from scipy.stats import gaussian_kde
import warnings
from mplscripts import extract_cloud_height, extract_info_mpl
import xarray as xr
warnings.filterwarnings('ignore')

# Variáveis para plotagem de gráficos
hours = mdates.HourLocator(interval = 1)
h_fmt = mdates.DateFormatter('%H:%M')

# %%
len(os.listdir('./NETCDF/2022'))
# Out:
# 13571

# %%
ds = xr.open_dataset('')

# %%
df = extract_cloud_height('/media/herian/KODAK/MPL LIDAR/LIDAR NETCDF/2022')

# %%
df
# Out:
#                data_hora  cloud_base1  cloud_peak1  cloud_top1  cloud_base2  \
# 0    2022-08-31 21:10:00          NaN          NaN         NaN          NaN
# 1    2022-08-31 21:20:00     1.199170     1.468983    1.948651          NaN
# 2    2022-08-31 21:30:00     1.588900     1.798755    2.008610          NaN
# 3    2022-08-31 21:40:00     1.558921     1.798755    2.008610          NaN
# 4    2022-08-31 21:50:00     1.498962     1.798755    2.008610          NaN
# ...                  ...          ...          ...         ...          ...
# 4286 2022-09-30 20:10:00     0.839419     1.049274    1.259128          NaN
# 4287 2022-09-30 20:20:00     0.839419     1.049274    1.259128          NaN
# 4288 2022-09-30 20:30:00     0.899377     1.079253    1.319087          NaN
# 4289 2022-09-30 20:40:00     0.899377     1.079253    1.319087     4.197094
# 4290 2022-09-30 20:50:00     0.899377     1.109232    1.319087     4.047198
#
# ...

# %%
# Extração dos dados de 2022
df1 = extract_info_mpl('./NETCDF/2022')
# Out:
# Extraindo as informações dos arquivos em:./NETCDF/2022...
# Por favor, aguarde!
# Encerrado

# %%
df1['data_hora'] = pd.to_datetime(df1['data_hora'])

# %%
df1.to_csv('LIDAR2022.csv', index=False)

# %%
len(os.listdir('./NETCDF/2023'))
# Out:
# 40088

# %%
df2 = extract_info_mpl('./NETCDF/2023')
# Out:
# Extraindo as informações dos arquivos em:./NETCDF/2023...
# Por favor, aguarde!
# Erro inesperado: Não foi possível extrair informações de MPL_5075_202310070400.nc
# <class 'Exception'>
# Extraindo informações dos demais arquivos
# Erro inesperado: Não foi possível extrair informações de MPL_5075_202310071650.nc
# <class 'Exception'>
# Extraindo informações dos demais arquivos
# Erro inesperado: Não foi possível extrair informações de MPL_5075_202308110900.nc
# <class 'Exception'>
# Extraindo informações dos demais arquivos
# Erro inesperado: Não foi possível extrair informações de MPL_5075_202310070630.nc
# <class 'Exception'>
# Extraindo informações dos demais arquivos
# Erro inesperado: Não foi possível extrair informações de MPL_5075_202306142306.nc
# <class 'Exception'>
# Extraindo informações dos demais arquivos
# Erro inesperado: Não foi possível extrair informações de MPL_5075_202308110640.nc
# <class 'Exception'>
# Extraindo informações dos demais arquivos
# ...
